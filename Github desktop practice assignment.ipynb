# %%
import pandas as pd
# basics_url="https://datasets.imdbws.com/title.basics.tsv.gz"
# basics = pd.read_csv(basics_url, sep='\t', low_memory=False)

# %%
# akas_url="https://datasets.imdbws.com/title.akas.tsv.gz"
# akas = pd.read_csv(akas_url, sep='\t', low_memory=False)

# %%
# ratings_url="https://datasets.imdbws.com/title.ratings.tsv.gz"
# ratings = pd.read_csv(ratings_url, sep='\t', low_memory=False)

# %%
import numpy as np
# basics.replace({'\\N':np.nan}, inplace = True)

# %%
# akas.replace({'\\N':np.nan}, inplace = True)

# %%
# ratings.replace({'\\N':np.nan}, inplace = True)

# %%
# basics = basics[~basics['runtimeMinutes'].isna()]

# %%
# basics = basics[~basics['genres'].isna()]

# %%
# basics = basics[basics['titleType'] == 'movie']

# %%
# basics = basics[~basics['startYear'].isna()]

# %%
# basics = basics[basics['startYear'].astype('int') >= 2000]

# %%
# basics = basics[basics['startYear'].astype('int') <= 2022]

# %%
# Exclude movies that are included in the documentary category.
# is_documentary = basics['genres'].str.contains('documentary',case=False)
# basics = basics[~is_documentary]

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
# keepers = basics['tconst'].isin(akas['titleId'][akas['region'] == 'US'])
# keepers
# Out:
# 34800        True
# 61111        True
# 67485        True
# 67663        True
# 80548        True
#             ...
# 10255667     True
# 10255706    False
# 10255751     True
# 10255835    False
# 10255925    False
# Name: tconst, Length: 147890, dtype: bool

# %%
# basics = basics[keepers]
# basics
# Out:
#              tconst titleType  \
# 34800     tt0035423     movie
# 61111     tt0062336     movie
# 67485     tt0068865     movie
# 67663     tt0069049     movie
# 80548     tt0082328     movie
# ...             ...       ...
# 10255124  tt9914942     movie
# 10255518  tt9915872     movie
# 10255658  tt9916170     movie
# 10255667  tt9916190     movie
# 10255751  tt9916362     movie
#
#                                                primaryTitle  \
# 34800                                        Kate & Leopold
# 61111     The Tango of the Widower and Its Distorting Mi...
# 67485                                   Lives of Performers
# 67663                            The Other Side of the Wind
# 80548                                    Embodiment of Evil
# ...                                                     ...
# 10255124                             Life Without Sara Amat
# 10255518                               The Last White Witch
# ...

# %%
# akas = akas[akas['region'] == 'US']
# akas
# Out:
#             titleId  ordering                                      title  \
# 5         tt0000001         6                                 Carmencita
# 14        tt0000002         7                     The Clown and His Dogs
# 33        tt0000005        10                           Blacksmith Scene
# 36        tt0000005         1                        Blacksmithing Scene
# 41        tt0000005         6                        Blacksmith Scene #1
# ...             ...       ...                                        ...
# 37550593  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 37550663  tt9916620         1                          The Copeland Case
# 37550752  tt9916702         1              Loving London: The Playground
# 37550795  tt9916756         1                   Pretty Pretty Black Girl
# 37550811  tt9916764         1                                         38
#
#          region language        types             attributes isOriginalTitle
# ...

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
# keepers = ratings['tconst'].isin(akas['titleId'][akas['region'] == 'US'])
# keepers
# Out:
# 0          True
# 1          True
# 4          True
# 5          True
# 6          True
#            ...
# 1361639    True
# 1361640    True
# 1361647    True
# 1361648    True
# 1361653    True
# Name: tconst, Length: 512347, dtype: bool

# %%
# ratngs = ratings[keepers]
# ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      2003
# 1        tt0000002            5.8       269
# 4        tt0000005            6.2      2681
# 5        tt0000006            5.0       183
# 6        tt0000007            5.4       839
# ...            ...            ...       ...
# 1361639  tt9916200            8.1       238
# 1361640  tt9916204            8.2       274
# 1361647  tt9916348            8.3        18
# 1361648  tt9916362            6.4      5575
# 1361653  tt9916428            3.5        17
#
# [512347 rows x 3 columns]

# %%
# basics.head()
# Out:
#           tconst titleType                                       primaryTitle  \
# 34800  tt0035423     movie                                     Kate & Leopold
# 61111  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 67485  tt0068865     movie                                Lives of Performers
# 67663  tt0069049     movie                         The Other Side of the Wind
# 80548  tt0082328     movie                                 Embodiment of Evil
#
#                                    originalTitle isAdult startYear endYear  \
# 34800                             Kate & Leopold       0      2001     NaN
# 61111  El tango del viudo y su espejo deformante       0      2020     NaN
# 67485                        Lives of Performers       0      2016     NaN
# 67663                 The Other Side of the Wind       0      2018     NaN
# 80548                      Encarnação do Demônio       0      2008     NaN
#
#       runtimeMinutes                  genres
# ...

# %%
# akas.head()
# Out:
#       titleId  ordering                   title region language        types  \
# 5   tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 14  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 33  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 36  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 41  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#                attributes isOriginalTitle
# 5                     NaN               0
# 14  literal English title               0
# 33                    NaN               0
# 36                    NaN               0
# 41                    NaN               0

# %%
# ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2003
# 1  tt0000002            5.8       269
# 4  tt0000005            6.2      2681
# 5  tt0000006            5.0       183
# 6  tt0000007            5.4       839

# %%
## Save current dataframe to file.
# basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)

# %%
## Save current dataframe to file.
# akas.to_csv("Data/title_akas.csv.gz",compression='gzip',index=False)

# %%
## Save current dataframe to file.
# ratings.to_csv("Data/title_ratings.csv.gz",compression='gzip',index=False)
